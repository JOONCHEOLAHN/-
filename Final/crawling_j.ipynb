# %% [markdown]
# ## 크롤링에 필요한 라이브러리

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup as bs
import math

import warnings
warnings.filterwarnings(action='ignore')

# pip install selenium
# pip install openpyxl

# %% [markdown]
# ## 크롬 웹브라우저 실행

# %%
driver = webdriver.Chrome("C:/AI/chromedriver_win32/chromedriver.exe")

# %% [markdown]
# ## 사이트 주소

# %%
driver.get("https://cafe.naver.com/mbticafe")
time.sleep(2)

# %% [markdown]
# ## 게시판 클릭  --> 게시판 루프 돌리기

# %%
keyword = 'INFP ♧ ENFP'
driver.find_element_by_link_text(keyword).click()

# %% [markdown]
# ## 게시판 프레임 접근

# %%
driver.switch_to.frame("cafe_main")

# %% [markdown]
# ## 게시글 50개씩

# %%
driver.find_element_by_css_selector("#listSizeSelectDiv").click()
driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/div/div[3]/ul/li[7]").click()

# %%
#crawling_list = []
no_app = []
title_app = []
nick_app  = []
like_app  = []
crawling_no = int(input('클롤링 할 글 개수를 입력 :'))
# Out:
# 클롤링 할 글 개수를 입력 : 50

# %%
# 크롤링 해야 할 페이지 계산
crawling_page = int(math.ceil(crawling_no / 50)+1)

try: 
    for page in range(1,crawling_page):
        # 페이지 클릭
        driver.find_element_by_link_text(str(page)).click()
        time.sleep(1)
        # 글 번호 수집
        no = [i.text for i in driver.find_elements_by_css_selector('.td_article')]
        no_split = [ni.split()[0] for ni in no]
        # 글 제목 수집
        title = [i.text for i in driver.find_elements_by_css_selector('.article')]
        # 작성자 수집
        nick = [i.text for i in driver.find_elements_by_css_selector('.p-nick .m-tcol-c')]
        # 좋아요 수집
        like = [i.text for i in driver.find_elements_by_css_selector('.td_likes')]
        # 수집 데이터 append
        no_app.append(no_split)
        title_app.append(title)
        nick_app.append(nick)
        like_app.append(like)
        # 10페이지 마다 프린트 & 다음 페이지로 클릭
        if str(page)[-1] == '0':
            print(int(page), 'page 크롤링 완료')
            driver.find_element_by_link_text('다음').click()
# 더이상 페이지가 존재하지 않을 시
except:
    print('더이상 페이지가 존재하지 않음')

# driver.close()
    
# 리스트안 리스트 분해
no_list = sum(no_app, [])
title_list = sum(title_app, [])
nick_list = sum(nick_app, [])
like_list = sum(like_app, [])

# 판다스화
df = pd.DataFrame({'번호':no_list,
                   '제목':title_list,
                   '작성자':nick_list,
                   '좋아요':like_list})
# 필독, 공지 삭제
df = df.drop(df[df['번호'] == '필독'].index)
df = df.drop(df[df['번호'] == '공지'].index)
df = df.reset_index(drop=True)

print('글 ', len(df), '개 크롤링 완료. \n크롤링 종료.', sep='')

df

# 저장
df.to_excel('crawler_naver cafe_게시판 {}.xlsx'.format(keyword))
# Out:
# 글 53개 크롤링 완료.
# 크롤링 종료.

# %%
df
# Out:
#         번호                                               제목          작성자 좋아요
# 0       추천                                 인프피분들 주목!! 눈물참는법     소라게 ENFJ  10
# 1       추천                              인프피 절친에게 물어봤더니 진짜래요   에취ENFJ 2w1   9
# 2       추천                            INFP 여러분 존재해줘서 고맙습니다.         산타오빠   8
# 3   563853                                         무기력 대처방법        해맑은인픞   0
# 4   563836                                     인프피 남성분들 ㅜㅠㅠ   ixtp bxgkk   0
# 5   563816                          INFP 인데 Ne를 안쓰는 것 같아요..    빅토리아 INFP   0
# 6   563736                                  엔프피도 집돌이일수 있나용?          잇쁘비   2
# 7   563708                            INFP 여러분 존재해줘서 고맙습니다.         산타오빠   8
# 8   563689                                     모험을 좋아하는 엔프피   ENFP 3w2 남   0
# 9   563685                              모고 풀고 현타온 엔프피 질문받아요        Enfp민   0
# 10  563663                                  Infp 여자 질문 받아요!       인픕피123   0
# 11  563660                           INFP-T 내향성 94퍼인 남자입니다.           혁2   0
# 12  563604                                 인프피에게 고맙다 힘이된다는말     lelelulu   1
# 13  563597                       요즘세상은 우리말보다 영어를 더 쓰는 거 같다.          레오나   1
# 14  563569                           답변요정 INFP 20대 남자 질문받아욤       블마INFP   0
# 15  563514                      INFP분들중에 건강염려증 있으신 분 안계신가요?      raramee   0
# 16  563477                              저 요즘 ENFP답지 않게 지냈더니       ENFP뇸뮥   2
# 17  563476                              INFP분들 이별후 재회 가능한가여          쪼꾸리   0
# 18  563428                                         엔프피 아들녀석      ENTJ 봉봉   0
# 19  563407                        BTS 뷔도 이러다가 INFP로 나오게 된듯.    아이스캔디ENfP   1
# 20  563326                         케이스 골라주세요 ! 엠비티아이도 같이요 !          엔뿌삐   0
# 21  563317                                 인프피 남자 질문 받습니다 !      JS INFP   0
# 22  563315                           ENFtP 엔프피도 연락 밀당하나요???         헤이마마   0
# 23  563314                         infp 인프피남자분들 금사빠 금사식인가요?           재윤   0
# 24  563299                                      모더나 맞고 왔습니다      INFP흰여우   0
# 25  563222                   인프피 짝남에 대해 질문! 도와주세요~ㅠ infp 남자     양양양 INFP   1
# 26  563188                         엔팁여잔데용... infp 남성분들 질문이용      entp 츄츄   1
# 27  563183                인생에서 가장 중요한 건 사람을 잘 만나야 한다고 생각한다.          레오나   8
# 28  563180                                       INFP 너무 좋아      동대남ENTJ   2
# 29  563170                             엔프피 금사빠 밈이 너무 싫어요!!!       U ENFP   0
# 30  563095                        여러분들은 콘서트에서 신나게 즐기는 편인가요?          레오나   2
# 31  563094                     인프피분들 나이먹어가면서 달라진다는게 느껴지시나요?       블루infp   1
# 32  563093            인프피님들, 먼저 살갑게 '인사만' 건네는거 어려워하시는 편인가요?      세월 INFP   2
# 33  563063                                       집가는길 질문받아요        Enfp민   0
# 34  563053                                       후우 현생 개빡세다  내가인프피라니 7w6   2
# 35  563043                   인프피들 이상이 높아서 괴리감 느낄 때 어떻게 하세요?        나도날몰라   2
# 36  563037                              인프피 절친에게 물어봤더니 진짜래요   에취ENFJ 2w1   9
# 37  562953                                인프피분들 동성에게 대하는 태도        인팁111   0
# 38  562909                   샤이니 태민같은 분위기를 갖고 싶다 (같은 인프피로서)     maktIXFX   0
# 39  562876                      [긴글주의] 스스로에게 있는 정신적인 문제에 대해          레오나   1
# 40  562862                                                .      INFP흰여우   0
# 41  562853                     Infp 남자분들 계시다면 특징좀 적어주고 가주세요          앙만두   0
# 42  562846                        다른 인프피분들도 연인한테 흐린눈 잘 하세요?       인픕피123   0
# 43  562825                     줄곧 전문가에게 상담받으라는 말을 듣기 싫었던 이유          레오나   0
# 44  562807  [긴글주의] 이 카페에다가 욕한 것도 아니고 자신을 돌아보며 말을 적은 것뿐인데..ㅠ          레오나   0
# 45  562786                                   INFP 여자 질문 받아영     귤랭이 INFP   0
# 46  562761                                오랜만에 검사해도 infp이네요      mo INFP   0
# 47  562730                                엔뿌삐분들! 이거 시그널일까요?       DDistp   1
# 48  562717                                    귀여운 인프피님들 질문!      esfj엣푸제   1
# 49  562714                                                .          레오나   1
# 50  562712                                다른 가치관을 잘 인정하는 이유     단다네 INFP   1
# 51  562699                       이곳에 비슷한 나이대가 있어서 다행인 거 같아요          레오나   4
# 52  562697                             엔프피 인프피 엔프제 인프제 칭구들은       연보라 엔쁩   0

# %%
# 저장
df.to_excel('crawler_naver cafe_게시판 {}.xlsx'.format(keyword))

# %% [markdown]
# ## 게시글 하나 클릭 --> 14루프 돌려야함 (게시글 번호)

# %%
article_list = driver.find_elements_by_css_selector('table > tbody > tr:nth-child(14) > td.td_article > div.board-list > div > a.article')
article_urls = [ i.get_attribute('href') for i in article_list ]

# %% [markdown]
# ----

# %%
# 요기까지

# %% [markdown]
# ----

# %%
res_list = []
# Beautifulsoup 활용
for article in article_urls:
    driver.get(article)
    # article도 switch_to.frame이 필수
    driver.switch_to.frame('cafe_main')
#     soup = bs(driver.page_source, 'html.parser')
#     # 게시글에서 제목 추출
#     title = soup.select('div.tit-box span.b')[0].get_text()
#     # 내용을 하나의 텍스트로 만든다. (띄어쓰기 단위)
#     content_tags = soup.select('#tbody')[0].select('p')
#     content = ' '.join([ tags.get_text() for tags in content_tags ])
#     # dict형태로 만들어 결과 list에 저장
#     res_list.append({'title' : title, 'content' : content})
#     # time.sleep 작업도 필요하다.
# # 결과 데이터프레임화
# cafe_df = pd.DataFrame(res_list)
# # csv파일로 추출
# cafe_df.to_csv('cafe_crawling.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\switch_to.py in frame(self, frame_reference)
#      86             try:
# ---> 87                 frame_reference = self._driver.find_element(By.ID, frame_reference)
#      88             except NoSuchElementException:
#
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="cafe_main"]"}
#   (Session info: chrome=95.0.4638.54)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003406F3+2492147]
# 	Ordinal0 [0x002D9BD1+2071505]
# 	Ordinal0 [0x001E2478+1057912]
# 	Ordinal0 [0x0020C964+1231204]
# 	Ordinal0 [0x00236B62+1403746]
# 	Ordinal0 [0x002257FA+1333242]
# 	Ordinal0 [0x00234F38+1396536]
# 	Ordinal0 [0x0022568B+1332875]
# 	Ordinal0 [0x002021D4+1188308]
# 	Ordinal0 [0x0020302F+1191983]
# 	GetHandleVerifier [0x004C67A6+1545030]
# 	GetHandleVerifier [0x0057105C+2243580]
# 	GetHandleVerifier [0x003CBC97+518199]
# 	GetHandleVerifier [0x003CAD80+514336]
# 	Ordinal0 [0x002DED2D+2092333]
# 	Ordinal0 [0x002E2EE8+2109160]
# 	Ordinal0 [0x002E3022+2109474]
# 	Ordinal0 [0x002ECB71+2149233]
# 	BaseThreadInitThunk [0x75A1FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77527A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77527A6E+238]
# 	(No symbol) [0x00000000]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\switch_to.py in frame(self, frame_reference)
#      89                 try:
# ---> 90                     frame_reference = self._driver.find_element(By.NAME, frame_reference)
#      91                 except NoSuchElementException:
#
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[name="cafe_main"]"}
#   (Session info: chrome=95.0.4638.54)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003406F3+2492147]
# 	Ordinal0 [0x002D9BD1+2071505]
# 	Ordinal0 [0x001E2478+1057912]
# 	Ordinal0 [0x0020C964+1231204]
# 	Ordinal0 [0x00236B62+1403746]
# 	Ordinal0 [0x002257FA+1333242]
# 	Ordinal0 [0x00234F38+1396536]
# 	Ordinal0 [0x0022568B+1332875]
# 	Ordinal0 [0x002021D4+1188308]
# 	Ordinal0 [0x0020302F+1191983]
# 	GetHandleVerifier [0x004C67A6+1545030]
# 	GetHandleVerifier [0x0057105C+2243580]
# 	GetHandleVerifier [0x003CBC97+518199]
# 	GetHandleVerifier [0x003CAD80+514336]
# 	Ordinal0 [0x002DED2D+2092333]
# 	Ordinal0 [0x002E2EE8+2109160]
# 	Ordinal0 [0x002E3022+2109474]
# 	Ordinal0 [0x002ECB71+2149233]
# 	BaseThreadInitThunk [0x75A1FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77527A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77527A6E+238]
# 	(No symbol) [0x00000000]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchFrameException                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10008/2936493608.py in <module>
#       4     driver.get(article)
#       5     # article도 switch_to.frame이 필수
# ----> 6     driver.switch_to.frame('cafe_main')
#       7 #     soup = bs(driver.page_source, 'html.parser')
#       8 #     # 게시글에서 제목 추출
#
# c:\ai\pythonproject\venv\lib\site-packages\selenium\webdriver\remote\switch_to.py in frame(self, frame_reference)
#      90                     frame_reference = self._driver.find_element(By.NAME, frame_reference)
#      91                 except NoSuchElementException:
# ---> 92                     raise NoSuchFrameException(frame_reference)
#      93
#      94         self._driver.execute(Command.SWITCH_TO_FRAME, {'id': frame_reference})
#
# NoSuchFrameException: Message: cafe_main

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
list = soup.select('ul.lst_site > li')

# %% [markdown]
# ## 네이버 로그인

# %%
# # 로그인 전용 화면
# driver.get('https://nid.naver.com/nidlogin.login')
# # 아이디와 비밀번호 입력
# driver.find_element_by_name('id').send_keys('아이디')
# driver.find_element_by_name('pw').send_keys('비밀번호')
# # 로그인 버튼 클릭
# driver.find_element_by_css_selector('#frmNIDLogin > fieldset > input').click()

# %%
# href 속성을 찾아 url을 리스트로 저장한다.
    ## 각 카페마다 태그의 형식이 다를 수 있으니 확인해야 한다. ( 태그.클래스명 )
    article_list = driver.find_elements_by_css_selector('span.aaa > a.m-tcol-c')
    article_urls = [ i.get_attribute('href') for i in article_list ]

# %% [markdown]
# ## 게시글로 접근

# %%
res_list = []
# Beautifulsoup 활용
for article in article_urls:
    driver.get(article)
    # article도 switch_to.frame이 필수
    driver.switch_to.frame('cafe_main')
    soup = bs(driver.page_source, 'html.parser')
    # 게시글에서 제목 추출
    title = soup.select('div.tit-box span.b')[0].get_text()
    # 내용을 하나의 텍스트로 만든다. (띄어쓰기 단위)
    content_tags = soup.select('#tbody')[0].select('p')
    content = ' '.join([ tags.get_text() for tags in content_tags ])
    # dict형태로 만들어 결과 list에 저장
    res_list.append({'title' : title, 'content' : content})
    # time.sleep 작업도 필요하다.
# 결과 데이터프레임화
cafe_df = pd.DataFrame(res_list)
# csv파일로 추출
cafe_df.to_csv('cafe_crawling.csv', index=False)

# %% [markdown]
# ## 카페 게시글 내용 수집

# %%
import pickle
from contextlib import suppress

for keyword in cafe.get("keywords"):
    df = pickle.load(open(save_path+"cafe_address_"+cafe.get("name")+"_"+keyword+".pkl", 'rb'))

    i=0
    contents_list = []   # 내용
    reply_list = []      # 댓글
    error_list = []      # 에러난 게시글

    while True:

        ### 수집 링크로 이동
        url = "https://cafe.naver.com"+df.loc[i,'link']
        idx_no = df.loc[i,'idx_no']    # 인덱스 번호
        driver.get(url)
        time.sleep( random.randint(2,5) )
        try:
            driver.switch_to.frame('cafe_main')
            time.sleep( random.randint(2,5) )
            r = driver.page_source
            page_soup = BeautifulSoup(r, "html.parser")
            content = page_soup.find('div', class_='ArticleContentBox')  

            ### 게시글 수집
            temp_dict={}
            temp_dict['idx_no'] = idx_no
            temp_dict['title'] = ""
            with suppress(AttributeError):   # 제목 없는 게시글
                temp_dict['title'] = content.find('h3',class_='title_text').text.strip()
            temp_dict['content'] = content.find("div", class_="article_viewer").text.strip()
            temp_dict['nick'] = content.find('div',class_='profile_info').find('a',class_='nickname').text.strip()
            temp_dict['date'] = content.find('div',class_='article_info').find('span',class_='date').text.strip()
            temp_dict['view'] = ""
            with suppress(AttributeError):
                temp_dict['view'] = content.find('div',class_='article_info').find('span',class_='count').text.strip()
            contents_list.append(temp_dict)

            ### 댓글 수집
            if content.find("div", class_="ReplyBox") is not None:   # 댓글 기능이 아예 없음  
                comment_num = content.find("div", class_="ReplyBox").find("a",class_="button_comment").find("strong").text
                if comment_num!='0':   # 댓글이 없음
                    comment = content.find("div", class_="CommentBox").find("ul",class_="comment_list").select("li")
                    
                    ### 댓글 구분
                    com_n=0    # 댓글
                    com_nn=0   # 대댓글
                    
                    for n in range(len(comment)):

                        if comment[n].get('class')==['CommentItem']:    # 댓글
                            com_n+=1; com_nn=0;
                            com_thread = str(com_n)+"-"+str(com_nn)
                            com_nn=1
                        elif comment[n].get('class')==['CommentItem', 'CommentItem--reply']:    # 대댓글
                            com_thread = str(com_n)+"-"+str(com_nn)
                            com_nn+=1

                        ### 댓글 내용 수집    
                        if comment[n].text.strip() != '삭제된 댓글입니다.':
                            com_nick = comment[n].find("a",class_="comment_nickname").text.strip()
                            com_date = comment[n].find("span",class_="comment_info_date").text.strip()
                            com_reply = comment[n].find("div",class_="comment_text_box").text.strip()
                            reply_list.append({'idx_no':idx_no, 'nick':com_nick, 'date':com_date, 'reply':com_reply, "thread":com_thread})
            i+=1

        except:
            i+=1
            ### 게시글을 볼 등급이 안됨
            if page_soup.find('strong', class_='emph') is not None:
                error_list.append({"error" :  page_soup.find('strong', class_='emph').text+"등급 필요"
                                   , "url" : url})
                pass
            ### 에러 따로 확인
            else:
                error_list.append({"error" : "에러 확인 필요"
                                   , "url" : url})
                pass

        ### 수집한 글 갯수만큼 반복
        if i == len(df):
            contents_df = pd.DataFrame(contents_list)
            contents_df.to_pickle("../../data/cafe/cafe_contents_"+cafe.get("name")+"_"+keyword+".pkl")
            reply_df = pd.DataFrame(reply_list)
            reply_df.to_pickle("../../data/cafe/cafe_replies_"+cafe.get("name")+"_"+keyword+".pkl")
            print("(현재시각) "+str(datetime.datetime.now())+": done")
            break
    
# 크롬 종료 
driver.quit()
