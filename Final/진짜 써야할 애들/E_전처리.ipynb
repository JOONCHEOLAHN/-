# %% [markdown]
# # 전처리

# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/final_mbti_data.csv')

# %%
df.head()
# Out:
#           type                                               text
# 0  신촌사과암살자enfj  일기) 주려던 건 아니었는데.여자친구도 사귀는데... 한 번도 받아보지 못한 사람이...
# 1         강신12  붕어빵 ㅋㅋ.이제 붕어빵의 계절이 돌아왔네요 요즘 날씨가 정말 추워지더라고요 어제도...
# 2     소라게 ENFJ  빼빼로 먹는날🤎.오늘은 빼빼로데이네요! 11월 11일!저는 11이라는 숫자가 모양이...
# 3     예사소년enfp  아침으로 먹을 맘모스빵을 사왔어요.😋.맘모스가 일찍부터 멸종된 이유가 있다.킥킥.새...
# 4    RDFS INTJ  미라클 모닝 8일차..좋은 아침입니당사실 요즘 미라클 모닝이 익숙해진 탓인지 감회가...

# %%
lists = ['estp', 'esfp', 'entp', 'enfp', 'estj', 'esfj', 'entj', 'enfj', 'istp', 'isfp', 'intp', 'infp', 'istj', 'isfj', 'intj', 'infj',
        '엔프피', '엔팁', '엔프제', '엔티제', '엣프피', '엣팁', '엣프제', '엣티제', '인프피', '인팁', '인프제', '인티제', '잇프피', '잇팁', '잇프제', '잇티제']

for idx, li in enumerate(lists):
    sum_count = df[df['type'].str.contains(li)]['type'].count()
    print(idx, li, sum_count)
# Out:
# 0 estp 67
# 1 esfp 28
# 2 entp 238
# 3 enfp 290
# 4 estj 60
# 5 esfj 58
# 6 entj 93
# 7 enfj 156
# 8 istp 302
# 9 isfp 203
# 10 intp 337
# 11 infp 659
# 12 istj 74
# 13 isfj 112
# 14 intj 322
# 15 infj 537
# 16 엔프피 25
# 17 엔팁 80
# 18 엔프제 17
# 19 엔티제 11
# 20 엣프피 1
# 21 엣팁 43
# 22 엣프제 8
# 23 엣티제 6
# 24 인프피 62
# 25 인팁 96
# 26 인프제 22
# 27 인티제 127
# 28 잇프피 114
# 29 잇팁 50
# 30 잇프제 42
# 31 잇티제 2

# %%
df_copy = df.copy()

# %%
df_copy['type'] = df_copy['type'].tolist()
df_copy['type'] = df_copy['type'].str.lower()

# %%
lists = ['estp', 'esfp', 'entp', 'enfp', 'estj', 'esfj', 'entj', 'enfj', 'istp', 'isfp', 'intp', 'infp', 'istj', 'isfj', 'intj', 'infj',
        '엔프피', '엔팁', '엔프제', '엔티제', '엣프피', '엣팁', '엣프제', '엣티제', '인프피', '인팁', '인프제', '인티제', '잇프피', '잇팁', '잇프제', '잇티제']

for idx, li in enumerate(lists):
    sum_count = df_copy[df_copy['type'].str.contains(li)]['type'].count()
    print(idx, li, sum_count)
    
    #16159
# Out:
# 0 estp 371
# 1 esfp 353
# 2 entp 1717
# 3 enfp 1115
# 4 estj 437
# 5 esfj 130
# 6 entj 544
# 7 enfj 648
# 8 istp 845
# 9 isfp 817
# 10 intp 1296
# 11 infp 2992
# 12 istj 370
# 13 isfj 785
# 14 intj 1535
# 15 infj 1498
# 16 엔프피 25
# 17 엔팁 80
# 18 엔프제 17
# 19 엔티제 11
# 20 엣프피 1
# 21 엣팁 43
# 22 엣프제 8
# 23 엣티제 6
# 24 인프피 62
# 25 인팁 96
# 26 인프제 22
# 27 인티제 127
# 28 잇프피 114
# 29 잇팁 50
# 30 잇프제 42
# 31 잇티제 2

# %%
df_copy1 = df_copy[df_copy['type'].str.contains('estp')]
df_copy1.insert(1, 'MBTI', 'estp') 
df_copy1
df_copy2 = df_copy[df_copy['type'].str.contains('엣팁')]
df_copy2.insert(1, 'MBTI', 'estp') 
df_copy2
df_copy3 = df_copy1.append(df_copy2)
df_copy3
df_copy3 = df_copy3.drop(['type'], axis=1)
df_copy3
# Out:
#        MBTI                                               text
# 1366   estp  배우자/애인을 아는 방법.httpsyoutu.ber3b7Tms7NPA 현실적인 조언...
# 1372   estp  사랑에 관한 생각정리.사랑이 두려운 것은 사랑이 깨지기 때문이 아니라 사랑이 변하기...
# 1387   estp  인셉션 영화 감상 (스포포함).httpsyoutu.beleslkTBWdo  예전에 ...
# 1400   estp  오늘 와 닿았던 명언.우리에게 필요한 것은 치유가 아니라, 상처와 더불어 살아갈 수...
# 2104   estp  유형 변화 / 처음으로 ESTJ 나왔네요..처음에는 ISFP였다가 검사해보면  ES...
# ...     ...                                                ...
# 23846  estp  처음으로 프로필 사진 올린 기념으로 글쓰기.제 귀염뽀짝한 프로필사진좀 보세요...제...
# 23926  estp                                  두두의 유형.뭘까요? 헷갈리네요
# 23967  estp  가스라이팅 시리즈가 엠헬을 장악했다.0 정말 대단해요... 가스라이팅 시리즈 정말 ...
# 24116  estp  n/s 차이의 밈.s도 사람이다. 여러 생각도 하고 상상을 하기도 한다.그런데 그들...
# 24177  estp  Exxx인 사람.정확히는 S,N T,F P,J 다 능숙하게 사용할 수 있는 사람입니...
#
# [414 rows x 2 columns]

# %%
df_copy4 = df_copy[df_copy['type'].str.contains('esfp')]
df_copy4.insert(1, 'MBTI', 'esfp') 

df_copy5 = df_copy[df_copy['type'].str.contains('엣프피')]
df_copy5.insert(1, 'MBTI', 'esfp') 

df_copy6 = df_copy4.append(df_copy5)
df_copy6
df_copy6 = df_copy6.drop(['type'], axis=1)
df_copy6
# Out:
#        MBTI                                               text
# 108    esfp  ㅉㅂㅇㄱ.2차 백신 맞으러 왔다어제 먼저 맞은 동생은 저녁에 괜찮다가새벽에 구토하고...
# 156    esfp  아닌 것.당신의 나이는 당신이 아니다.당신이 입는 옷의 크기도 몸무게와 머리 색깔도...
# 220    esfp  ㄱㅈㅇㄱ.하루하루가 빨리가는 느낌이다그만큼 알차게 보낸 한주였다는 뜻이겠지오늘도 운...
# 232    esfp  결국 인싸든 아싸든 행복을 찾는게 중요한듯(진지함 주의).몇번 언급됬다시피전 지금은...
# 248    esfp              학교에서 빡공한 후 먹는 뽀글이. 꿀맛임항상 일끝나면 왜이리 맛있나
# ...     ...                                                ...
# 24807  esfp  우월하다고 느끼는가?.다른 사람을 보며 비웃는다.행복한가?자신과 남을 비교했을 때 ...
# 25212  esfp  왜 자꾸 쳐다볼까요...!!.저는 평소 톡할 때 반존대를 자주 쓰는 편인,인팁이도 ...
# 25373  esfp  책 보다가 mbti 동물 테스트도 발견!.저 엣프피중에서도 킹인싸 성격이라 친구들한...
# 25532  esfp                        MBTI연애 유형 :).엣프제 나오신분 있으신가요
# 6870   esfp  엔프피랑 엣프피랑 많이 다른가요?.전체적인 성향이요!뭐 하나에 잘 꽂히고 올인하고 ...
#
# [354 rows x 2 columns]

# %%
df_copy_a = df_copy6.append(df_copy3)
df_copy_a
# Out:
#        MBTI                                               text
# 108    esfp  ㅉㅂㅇㄱ.2차 백신 맞으러 왔다어제 먼저 맞은 동생은 저녁에 괜찮다가새벽에 구토하고...
# 156    esfp  아닌 것.당신의 나이는 당신이 아니다.당신이 입는 옷의 크기도 몸무게와 머리 색깔도...
# 220    esfp  ㄱㅈㅇㄱ.하루하루가 빨리가는 느낌이다그만큼 알차게 보낸 한주였다는 뜻이겠지오늘도 운...
# 232    esfp  결국 인싸든 아싸든 행복을 찾는게 중요한듯(진지함 주의).몇번 언급됬다시피전 지금은...
# 248    esfp              학교에서 빡공한 후 먹는 뽀글이. 꿀맛임항상 일끝나면 왜이리 맛있나
# ...     ...                                                ...
# 23846  estp  처음으로 프로필 사진 올린 기념으로 글쓰기.제 귀염뽀짝한 프로필사진좀 보세요...제...
# 23926  estp                                  두두의 유형.뭘까요? 헷갈리네요
# 23967  estp  가스라이팅 시리즈가 엠헬을 장악했다.0 정말 대단해요... 가스라이팅 시리즈 정말 ...
# 24116  estp  n/s 차이의 밈.s도 사람이다. 여러 생각도 하고 상상을 하기도 한다.그런데 그들...
# 24177  estp  Exxx인 사람.정확히는 S,N T,F P,J 다 능숙하게 사용할 수 있는 사람입니...
#
# [768 rows x 2 columns]

# %%
df_copy7 = df_copy[df_copy['type'].str.contains('entp')]
df_copy7.insert(1, 'MBTI', 'entp') 

df_copy8 = df_copy[df_copy['type'].str.contains('엔팁')]
df_copy8.insert(1, 'MBTI', 'entp') 

df_copy9 = df_copy7.append(df_copy8)
df_copy9 = df_copy9.drop(['type'], axis=1)
df_copy9
# df_copy9 = df_copy9.drop(['type'], axis=1)
# df_copy9
# Out:
#        MBTI                                               text
# 7      entp                             My type.외향이 이렇게 높나 어닌데
# 11     entp  당연한 이야기를 일깨워드리겠읍니다.여러분 모든과 똑같이 맞춰 갈 필요 없습니다. 그...
# 13     entp                         님들은 어디서 동기부여를 얻으시나요.제곧내이비다
# 68     entp  오늘의 연애 tmi.여친 정수리에 낙엽이 떨어져 있길래 다른 사람이 보면 곤란하니까...
# 128    entp             먼지가 또 많아졌다.짱깨가 석탄 땐다............콜록콜록콜록
# ...     ...                                                ...
# 22965  entp  엔팁 성격.친구가 저한테 애들이 저는 선이 있어서 잘 못넘겠다고 했대요친해지는건 쉬...
# 23091  entp  가끔 f들의 도덕적 잣대를 이해하기 힘들어요.가끔 제 주변 f유형들이 충분히 이견이...
# 23347  entp  찍먹 vs 부먹.오늘 찍먹파에서 잠깐 나와중도층인 쳐먹으로 탕수육을 혼내줬는데역시 ...
# 23649  entp  드립 욕심.이게 언제부터 였는지 모르겠으나 초등학생 시절부터 웃기는 아이, 이유 없...
# 23719  entp  이런 상황에 맞닥뜨린다면?.httpsyoutu.be4LCEYE4s0A 1. 괜히 도...
#
# [1797 rows x 2 columns]

# %%
df_copy_a = df_copy_a.append(df_copy9)
df_copy_a
# Out:
#        MBTI                                               text
# 108    esfp  ㅉㅂㅇㄱ.2차 백신 맞으러 왔다어제 먼저 맞은 동생은 저녁에 괜찮다가새벽에 구토하고...
# 156    esfp  아닌 것.당신의 나이는 당신이 아니다.당신이 입는 옷의 크기도 몸무게와 머리 색깔도...
# 220    esfp  ㄱㅈㅇㄱ.하루하루가 빨리가는 느낌이다그만큼 알차게 보낸 한주였다는 뜻이겠지오늘도 운...
# 232    esfp  결국 인싸든 아싸든 행복을 찾는게 중요한듯(진지함 주의).몇번 언급됬다시피전 지금은...
# 248    esfp              학교에서 빡공한 후 먹는 뽀글이. 꿀맛임항상 일끝나면 왜이리 맛있나
# ...     ...                                                ...
# 22965  entp  엔팁 성격.친구가 저한테 애들이 저는 선이 있어서 잘 못넘겠다고 했대요친해지는건 쉬...
# 23091  entp  가끔 f들의 도덕적 잣대를 이해하기 힘들어요.가끔 제 주변 f유형들이 충분히 이견이...
# 23347  entp  찍먹 vs 부먹.오늘 찍먹파에서 잠깐 나와중도층인 쳐먹으로 탕수육을 혼내줬는데역시 ...
# 23649  entp  드립 욕심.이게 언제부터 였는지 모르겠으나 초등학생 시절부터 웃기는 아이, 이유 없...
# 23719  entp  이런 상황에 맞닥뜨린다면?.httpsyoutu.be4LCEYE4s0A 1. 괜히 도...
#
# [2565 rows x 2 columns]

# %%
df_copy10 = df_copy[df_copy['type'].str.contains('enfp')]
df_copy10.insert(1, 'MBTI', 'enfp') 

df_copy11 = df_copy[df_copy['type'].str.contains('엔프피')]
df_copy11.insert(1, 'MBTI', 'enfp') 

df_copy12 = df_copy10.append(df_copy11)
df_copy12 = df_copy12.drop(['type'], axis=1)
df_copy12
# Out:
#        MBTI                                               text
# 3      enfp  아침으로 먹을 맘모스빵을 사왔어요.😋.맘모스가 일찍부터 멸종된 이유가 있다.킥킥.새...
# 47     enfp  새벽 떡이 얼마나 맛있는지 모르겠어요 😋.너무 일찍오면 썰어서 판다는 팥고물 인절미...
# 60     enfp  빼빼로 받았어요! 🍪. 개인적으로 추천드리는 꼬깔콘 새우마요맛 리미티드 에디션큭큭 ...
# 123    enfp  긍정일기.오늘은 수행평가가 2개 있었다. 둘 다 잘 끝냈다!!이제 당분간 수행 평가...
# 186    enfp  "좋은 아침입니다" 는 🙋‍♂️.My meal. 대한민국 3대 헛소리 중 하나래요....
# ...     ...                                                ...
# 16907  enfp  mbti 별 초능력 공감하시나요?? 플로타곤 영상 유.제가 연재하고 있는 시리즈에요...
# 20028  enfp  intj,istj,enfj,enfp가 보는 enfp.어떤가요?? 그리고 엔프피가 친...
# 20339  enfp  본인 엔프피! 질문받아요.잠은 안오고 가을 바람은 선선하고질문온거 대답은 하고 싶고...
# 22054  enfp                    enfj분들 한번만 봐주세여ㅠㅠ.다들 조언 너무 감사해요
# 23442  enfp  퐁퐁두두 첫 최종진화 그리고 그 과정. 실제로 저는 예술계통이자 왜? 빌런입니다생각...
#
# [1140 rows x 2 columns]

# %%
df_copy_a = df_copy_a.append(df_copy12)
df_copy_a
# Out:
#        MBTI                                               text
# 108    esfp  ㅉㅂㅇㄱ.2차 백신 맞으러 왔다어제 먼저 맞은 동생은 저녁에 괜찮다가새벽에 구토하고...
# 156    esfp  아닌 것.당신의 나이는 당신이 아니다.당신이 입는 옷의 크기도 몸무게와 머리 색깔도...
# 220    esfp  ㄱㅈㅇㄱ.하루하루가 빨리가는 느낌이다그만큼 알차게 보낸 한주였다는 뜻이겠지오늘도 운...
# 232    esfp  결국 인싸든 아싸든 행복을 찾는게 중요한듯(진지함 주의).몇번 언급됬다시피전 지금은...
# 248    esfp              학교에서 빡공한 후 먹는 뽀글이. 꿀맛임항상 일끝나면 왜이리 맛있나
# ...     ...                                                ...
# 16907  enfp  mbti 별 초능력 공감하시나요?? 플로타곤 영상 유.제가 연재하고 있는 시리즈에요...
# 20028  enfp  intj,istj,enfj,enfp가 보는 enfp.어떤가요?? 그리고 엔프피가 친...
# 20339  enfp  본인 엔프피! 질문받아요.잠은 안오고 가을 바람은 선선하고질문온거 대답은 하고 싶고...
# 22054  enfp                    enfj분들 한번만 봐주세여ㅠㅠ.다들 조언 너무 감사해요
# 23442  enfp  퐁퐁두두 첫 최종진화 그리고 그 과정. 실제로 저는 예술계통이자 왜? 빌런입니다생각...
#
# [3705 rows x 2 columns]

# %%
df_copy13 = df_copy[df_copy['type'].str.contains('esfj')]
df_copy13.insert(1, 'MBTI', 'esfj') 

df_copy14 = df_copy[df_copy['type'].str.contains('엣프제')]
df_copy14.insert(1, 'MBTI', 'esfj') 

df_copy15 = df_copy13.append(df_copy14)
df_copy15 = df_copy15.drop(['type'], axis=1)
df_copy15
# Out:
#        MBTI                                               text
# 334    esfj  내가 ESFJ라는 걸 알고 분석글을 작성하기 시작했을 때.질문을 받기 시작했었는데정...
# 1598   esfj  보고 싶은 엠헬 인기 멤버들(이라고 쓰고 썩은 물 회상기).엠헬을 하다 보면 참 여...
# 1737   esfj  나이가 들었나 봅니다😵.어느 순간 1인 1닭이 불가능해지더니오늘 점심 시간에 입맛이...
# 1853   esfj  엣프제(esfj)가 느끼는 나의 단점 및 고쳐야할 부분.1. 기분이 태도가 되는 경...
# 1959   esfj  다른분이 마스크 벗은 모습을 보면 이상하지 않아요??.뜬금없지만 그냥 궁금해서 여쭤...
# ...     ...                                                ...
# 2491   esfj  아이돌이 팬에게 미치는 영향 (정신적 지주).왜 세상은 높고 나는 그 벽보다 크지 ...
# 16760  esfj  날씨가 진짜 넘 춥네여 ,,.분명 얼마 전까지만 해도 덥다고 반팔에 에어컨을 틀어주...
# 16841  esfj  다들 ESFJ 어떻게 생각하시나요 !?!.오늘 게시글을 많이 올리는 기분이 드는데,...
# 16847  esfj  다들 회사에서 일 없을 때 뭐하시나용...저는 보통 핸드폰으로 인스타 구경하기도 하...
# 23005  esfj  유형 분석1) ISFJ, ESTJ, INTJ.안녕하세요 엣프제임당저번에 요론 비슷한...
#
# [138 rows x 2 columns]

# %%
df_copy_a = df_copy_a.append(df_copy15)
df_copy_a
# Out:
#        MBTI                                               text
# 108    esfp  ㅉㅂㅇㄱ.2차 백신 맞으러 왔다어제 먼저 맞은 동생은 저녁에 괜찮다가새벽에 구토하고...
# 156    esfp  아닌 것.당신의 나이는 당신이 아니다.당신이 입는 옷의 크기도 몸무게와 머리 색깔도...
# 220    esfp  ㄱㅈㅇㄱ.하루하루가 빨리가는 느낌이다그만큼 알차게 보낸 한주였다는 뜻이겠지오늘도 운...
# 232    esfp  결국 인싸든 아싸든 행복을 찾는게 중요한듯(진지함 주의).몇번 언급됬다시피전 지금은...
# 248    esfp              학교에서 빡공한 후 먹는 뽀글이. 꿀맛임항상 일끝나면 왜이리 맛있나
# ...     ...                                                ...
# 2491   esfj  아이돌이 팬에게 미치는 영향 (정신적 지주).왜 세상은 높고 나는 그 벽보다 크지 ...
# 16760  esfj  날씨가 진짜 넘 춥네여 ,,.분명 얼마 전까지만 해도 덥다고 반팔에 에어컨을 틀어주...
# 16841  esfj  다들 ESFJ 어떻게 생각하시나요 !?!.오늘 게시글을 많이 올리는 기분이 드는데,...
# 16847  esfj  다들 회사에서 일 없을 때 뭐하시나용...저는 보통 핸드폰으로 인스타 구경하기도 하...
# 23005  esfj  유형 분석1) ISFJ, ESTJ, INTJ.안녕하세요 엣프제임당저번에 요론 비슷한...
#
# [3843 rows x 2 columns]

# %%
df_copy16 = df_copy[df_copy['type'].str.contains('estj')]
df_copy16.insert(1, 'MBTI', 'estj') 

df_copy17 = df_copy[df_copy['type'].str.contains('엣티제')]
df_copy17.insert(1, 'MBTI', 'estj') 

df_copy18 = df_copy16.append(df_copy17)
df_copy18 = df_copy18.drop(['type'], axis=1)
df_copy18
# Out:
#        MBTI                                               text
# 283    estj  프로게이머 대선배들 끼리 싸우면 생기는 일.httpswww.youtube.comwa...
# 284    estj  어떤 프로게이머를 억만장자로 만들어준 전략과 사건.httpswww.youtube.c...
# 287    estj  오늘도 격투기 보겠습니다.httpswww.youtube.comwatch?v0OHPY...
# 291    estj        포켓몬이 디지몬처럼 진화하는 영상.httpsyoutu.be9GWSxMm05vg
# 294    estj  캐치마인드 현 주소.Loading... playerlikesoundmutesound...
# ...     ...                                                ...
# 5467   estj  임시적 내향화.3주째.집에있는게 천국이고 행복이다.집에있으면 답답해 미칠것같고 나가...
# 6174   estj                                 저도 해봤어요.어떤 유형 같나요?
# 6881   estj  한사랑산악회 회원들 유형 감별해주세요.요즘 유튜브에서 너무 재밌게 보고 있는데  갑...
# 14295  estj  개인적으로 사이다, 팩트폭력, 참교육 이런 말들 너무 싫어요.정말 부조리함을 올바르...
# 18088  estj  남사친/여사친은 진짜 친구일까요?.무기명 투표 중남사친 여사친친구에게 고백받은 적이...
#
# [443 rows x 2 columns]

# %%
df_copy_a = df_copy_a.append(df_copy18)
df_copy_a
# Out:
#        MBTI                                               text
# 108    esfp  ㅉㅂㅇㄱ.2차 백신 맞으러 왔다어제 먼저 맞은 동생은 저녁에 괜찮다가새벽에 구토하고...
# 156    esfp  아닌 것.당신의 나이는 당신이 아니다.당신이 입는 옷의 크기도 몸무게와 머리 색깔도...
# 220    esfp  ㄱㅈㅇㄱ.하루하루가 빨리가는 느낌이다그만큼 알차게 보낸 한주였다는 뜻이겠지오늘도 운...
# 232    esfp  결국 인싸든 아싸든 행복을 찾는게 중요한듯(진지함 주의).몇번 언급됬다시피전 지금은...
# 248    esfp              학교에서 빡공한 후 먹는 뽀글이. 꿀맛임항상 일끝나면 왜이리 맛있나
# ...     ...                                                ...
# 5467   estj  임시적 내향화.3주째.집에있는게 천국이고 행복이다.집에있으면 답답해 미칠것같고 나가...
# 6174   estj                                 저도 해봤어요.어떤 유형 같나요?
# 6881   estj  한사랑산악회 회원들 유형 감별해주세요.요즘 유튜브에서 너무 재밌게 보고 있는데  갑...
# 14295  estj  개인적으로 사이다, 팩트폭력, 참교육 이런 말들 너무 싫어요.정말 부조리함을 올바르...
# 18088  estj  남사친/여사친은 진짜 친구일까요?.무기명 투표 중남사친 여사친친구에게 고백받은 적이...
#
# [4286 rows x 2 columns]

# %%
df_copy19 = df_copy[df_copy['type'].str.contains('entj')]
df_copy19.insert(1, 'MBTI', 'entj') 

df_copy20 = df_copy[df_copy['type'].str.contains('엔티제')]
df_copy20.insert(1, 'MBTI', 'entj') 

df_copy21 = df_copy19.append(df_copy20)
df_copy21 = df_copy21.drop(['type'], axis=1)

df_copy_a = df_copy_a.append(df_copy21)
df_copy_a
# Out:
#        MBTI                                               text
# 108    esfp  ㅉㅂㅇㄱ.2차 백신 맞으러 왔다어제 먼저 맞은 동생은 저녁에 괜찮다가새벽에 구토하고...
# 156    esfp  아닌 것.당신의 나이는 당신이 아니다.당신이 입는 옷의 크기도 몸무게와 머리 색깔도...
# 220    esfp  ㄱㅈㅇㄱ.하루하루가 빨리가는 느낌이다그만큼 알차게 보낸 한주였다는 뜻이겠지오늘도 운...
# 232    esfp  결국 인싸든 아싸든 행복을 찾는게 중요한듯(진지함 주의).몇번 언급됬다시피전 지금은...
# 248    esfp              학교에서 빡공한 후 먹는 뽀글이. 꿀맛임항상 일끝나면 왜이리 맛있나
# ...     ...                                                ...
# 8164   entj  자신의 좌우명.자신이 살아가면서 기준이 되는 좌우명이 있나요? 자신의 좌우명을 댓글...
# 8166   entj  _NTJ 유형들은.본 글은 ENTJ가 주관적으로 생각하여 쓴 글로 사람마다 다르게 ...
# 8768   entj  미생캐릭터들 mbti 뭘까여?.엔티제로서 장그래 왜케 싫져...?..영이랑백기가 젤...
# 17959  entj                                 저도 눈궁예 그거 해볼래요.으하하
# 25395  entj                       T 100%.form Q검서 했는데 정확해서 소름
#
# [4841 rows x 2 columns]

# %%
df_copy22 = df_copy[df_copy['type'].str.contains('enfj')]
df_copy22.insert(1, 'MBTI', 'enfj') 

df_copy23 = df_copy[df_copy['type'].str.contains('엔프제')]
df_copy23.insert(1, 'MBTI', 'enfj') 

df_copy24 = df_copy22.append(df_copy23)
df_copy24 = df_copy24.drop(['type'], axis=1)

df_copy_a = df_copy_a.append(df_copy24)
df_copy_a
# Out:
#        MBTI                                               text
# 108    esfp  ㅉㅂㅇㄱ.2차 백신 맞으러 왔다어제 먼저 맞은 동생은 저녁에 괜찮다가새벽에 구토하고...
# 156    esfp  아닌 것.당신의 나이는 당신이 아니다.당신이 입는 옷의 크기도 몸무게와 머리 색깔도...
# 220    esfp  ㄱㅈㅇㄱ.하루하루가 빨리가는 느낌이다그만큼 알차게 보낸 한주였다는 뜻이겠지오늘도 운...
# 232    esfp  결국 인싸든 아싸든 행복을 찾는게 중요한듯(진지함 주의).몇번 언급됬다시피전 지금은...
# 248    esfp              학교에서 빡공한 후 먹는 뽀글이. 꿀맛임항상 일끝나면 왜이리 맛있나
# ...     ...                                                ...
# 13616  enfj  교생이 끝나가는 시점에서(수업실연은 너무 힘들어).제가 학창시절 선생님은 그냥 권위...
# 13695  enfj  뮤지컬 좋아하시는분?✋(그레이트 코멧 후기 뒷북).어제 토요일 서울 유니버셜아트센터...
# 13771  enfj  나와 사랑하는 사람을 지키기 위해(가다실9가 접종1차).조세호씨가 다이어트를 하시고...
# 13790  enfj  오랜만입니다 여러분✋ (인류애 밖에 없는 유형이 🐶에게 던지는 요즘).코로나 시작되...
# 24005  enfj                                             7/3.73
#
# [5506 rows x 2 columns]

# %%
df_copy101 = df_copy[df_copy['type'].str.contains('infp')]
df_copy101.insert(1, 'MBTI', 'infp') 
df_copy102 = df_copy[df_copy['type'].str.contains('인프피')]
df_copy102.insert(1, 'MBTI', 'infp') 
df_copy103 = df_copy101.append(df_copy102)
df_copy103 = df_copy103.drop(['type'], axis=1)

# %%
df_copy104 = df_copy[df_copy['type'].str.contains('intp')]
df_copy104.insert(1, 'MBTI', 'intp') 
df_copy105 = df_copy[df_copy['type'].str.contains('인팁')]
df_copy105.insert(1, 'MBTI', 'intp') 
df_copy106 = df_copy104.append(df_copy105)
df_copy106 = df_copy106.drop(['type'], axis=1)

# %%
df_copy107 = df_copy[df_copy['type'].str.contains('infj')]
df_copy107.insert(1, 'MBTI', 'infj') 
df_copy108 = df_copy[df_copy['type'].str.contains('인프제')]
df_copy108.insert(1, 'MBTI', 'infj') 
df_copy109 = df_copy107.append(df_copy108)
df_copy109 = df_copy109.drop(['type'], axis=1)

# %%
df_copy110 = df_copy[df_copy['type'].str.contains('intj')]
df_copy110.insert(1, 'MBTI', 'intj') 
df_copy111 = df_copy[df_copy['type'].str.contains('인티제')]
df_copy111.insert(1, 'MBTI', 'intj') 
df_copy112 = df_copy110.append(df_copy111)
df_copy112 = df_copy112.drop(['type'], axis=1)

# %%
df_copy113 = df_copy[df_copy['type'].str.contains('isfp')]
df_copy113.insert(1, 'MBTI', 'isfp') 
df_copy114 = df_copy[df_copy['type'].str.contains('잇프피')]
df_copy114.insert(1, 'MBTI', 'isfp') 
df_copy115 = df_copy113.append(df_copy114)
df_copy115 = df_copy115.drop(['type'], axis=1)

# %%
df_copy116 = df_copy[df_copy['type'].str.contains('istp')]
df_copy116.insert(1, 'MBTI', 'istp') 
df_copy117 = df_copy[df_copy['type'].str.contains('잇팁')]
df_copy117.insert(1, 'MBTI', 'istp') 
df_copy118 = df_copy116.append(df_copy117)
df_copy118 = df_copy118.drop(['type'], axis=1)

# %%
df_copy119 = df_copy[df_copy['type'].str.contains('isfj')]
df_copy119.insert(1, 'MBTI', 'isfj') 
df_copy120 = df_copy[df_copy['type'].str.contains('잇프제')]
df_copy120.insert(1, 'MBTI', 'isfj') 
df_copy121 = df_copy119.append(df_copy120)
df_copy121 = df_copy121.drop(['type'], axis=1)

# %%
df_copy122 = df_copy[df_copy['type'].str.contains('istj')]
df_copy122.insert(1, 'MBTI', 'istj') 
df_copy123 = df_copy[df_copy['type'].str.contains('잇티제')]
df_copy123.insert(1, 'MBTI', 'istj') 
df_copy124 = df_copy122.append(df_copy123)
df_copy124 = df_copy124.drop(['type'], axis=1)

# %%
df_copy125 = df_copy103.append(df_copy106)

df_copy126 = df_copy109.append(df_copy112)

df_copy127 = df_copy115.append(df_copy118)

df_copy128 = df_copy121.append(df_copy124)

df_copy129 = df_copy125.append(df_copy126)

df_copy130 = df_copy127.append(df_copy128)

df_copy131 = df_copy129.append(df_copy130)

df_copy_a = df_copy131.append(df_copy_a)
df_copy_a
# Out:
#        MBTI                                               text
# 21     infp  우울 일기.회사에서 돈과 관련된 대형 실수를 저질렀다...금액은 크지 않지만 누군가...
# 23     infp  엠헬에서 만난 귀인께 드리는 글.조언과 저의 조언 느낀점이에요저에게는 귀인이신 분....
# 45     infp  나만의 미라클 모닝.저한테 미라클 모닝은 사실이렇게 무사히 일어나서 지각 없이 출근...
# 82     infp  오늘 하루도 감사한 마음으로.하고 싶은 일을 하는데도해야 할 일처럼 느껴질 때 오는...
# 85     infp  Te를 잘 쓸 수 있었다. (어제 쓴 글).오늘 하루 동안만큼은 잘 쓸 수 있었다....
# ...     ...                                                ...
# 13616  enfj  교생이 끝나가는 시점에서(수업실연은 너무 힘들어).제가 학창시절 선생님은 그냥 권위...
# 13695  enfj  뮤지컬 좋아하시는분?✋(그레이트 코멧 후기 뒷북).어제 토요일 서울 유니버셜아트센터...
# 13771  enfj  나와 사랑하는 사람을 지키기 위해(가다실9가 접종1차).조세호씨가 다이어트를 하시고...
# 13790  enfj  오랜만입니다 여러분✋ (인류애 밖에 없는 유형이 🐶에게 던지는 요즘).코로나 시작되...
# 24005  enfj                                             7/3.73
#
# [16159 rows x 2 columns]

# %%
df_copy_a.to_csv('./datasets/MBTI_fin.csv')

# %%
df = pd.read_csv("./datasets/MBTI_fin.csv")
df
# Out:
#        Unnamed: 0  MBTI                                               text
# 0              21  infp  우울 일기.회사에서 돈과 관련된 대형 실수를 저질렀다...금액은 크지 않지만 누군가...
# 1              23  infp  엠헬에서 만난 귀인께 드리는 글.조언과 저의 조언 느낀점이에요저에게는 귀인이신 분....
# 2              45  infp  나만의 미라클 모닝.저한테 미라클 모닝은 사실이렇게 무사히 일어나서 지각 없이 출근...
# 3              82  infp  오늘 하루도 감사한 마음으로.하고 싶은 일을 하는데도해야 할 일처럼 느껴질 때 오는...
# 4              85  infp  Te를 잘 쓸 수 있었다. (어제 쓴 글).오늘 하루 동안만큼은 잘 쓸 수 있었다....
# ...           ...   ...                                                ...
# 16154       13616  enfj  교생이 끝나가는 시점에서(수업실연은 너무 힘들어).제가 학창시절 선생님은 그냥 권위...
# 16155       13695  enfj  뮤지컬 좋아하시는분?✋(그레이트 코멧 후기 뒷북).어제 토요일 서울 유니버셜아트센터...
# 16156       13771  enfj  나와 사랑하는 사람을 지키기 위해(가다실9가 접종1차).조세호씨가 다이어트를 하시고...
# 16157       13790  enfj  오랜만입니다 여러분✋ (인류애 밖에 없는 유형이 🐶에게 던지는 요즘).코로나 시작되...
# 16158       24005  enfj                                             7/3.73
#
# [16159 rows x 3 columns]

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.to_csv("./datasets/MBTI_fin.csv")

# %%
df = pd.read_csv("./datasets/MBTI_fin.csv")
df.drop(['Unnamed: 0'], axis=1, inplace=True)
print(df)
# Out:
#        MBTI                                               text
# 0      infp  우울 일기.회사에서 돈과 관련된 대형 실수를 저질렀다...금액은 크지 않지만 누군가...
# 1      infp  엠헬에서 만난 귀인께 드리는 글.조언과 저의 조언 느낀점이에요저에게는 귀인이신 분....
# 2      infp  나만의 미라클 모닝.저한테 미라클 모닝은 사실이렇게 무사히 일어나서 지각 없이 출근...
# 3      infp  오늘 하루도 감사한 마음으로.하고 싶은 일을 하는데도해야 할 일처럼 느껴질 때 오는...
# 4      infp  Te를 잘 쓸 수 있었다. (어제 쓴 글).오늘 하루 동안만큼은 잘 쓸 수 있었다....
# ...     ...                                                ...
# 16154  enfj  교생이 끝나가는 시점에서(수업실연은 너무 힘들어).제가 학창시절 선생님은 그냥 권위...
# 16155  enfj  뮤지컬 좋아하시는분?✋(그레이트 코멧 후기 뒷북).어제 토요일 서울 유니버셜아트센터...
# 16156  enfj  나와 사랑하는 사람을 지키기 위해(가다실9가 접종1차).조세호씨가 다이어트를 하시고...
# 16157  enfj  오랜만입니다 여러분✋ (인류애 밖에 없는 유형이 🐶에게 던지는 요즘).코로나 시작되...
# 16158  enfj                                             7/3.73
#
# [16159 rows x 2 columns]
