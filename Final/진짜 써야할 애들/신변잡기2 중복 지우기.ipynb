# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./신변잡기2.csv')
                 
df.head()
# Out:
#    seq                 title       writer  \
# 0    1                붕어빵 ㅋㅋ         강신12
# 1    2              빼빼로 먹는날🤎     소라게 ENFJ
# 2    3  아침으로 먹을 맘모스빵을 사왔어요.😋     예사소년enfp
# 3    4           미라클 모닝 8일차.    RDFS INTJ
# 4    5   인팁이 분석능력 있어서 참 좋다.,  병맛intpA 5w6
#
#                                              content
# 0  이제 붕어빵의 계절이 돌아왔네요 요즘 날씨가 정말 추워지더라고요 어제도 진짜 깜짝 ...
# 1  오늘은 빼빼로데이네요! 11월 11일!저는 11이라는 숫자가 모양이 이뻐서 좋아해요...
# 2  맘모스가 일찍부터 멸종된 이유가 있다.킥킥.새벽부터 부리나케 나가서 맘모스빵을 사왔...
# 3  좋은 아침입니당사실 요즘 미라클 모닝이 익숙해진 탓인지 감회가 그리 새롭지가 않아요...
# 4  우리 인팁 장점 별로 없지만 분석능력 하나는 좋아요.estj남편이 사업하는데 사람가...

# %%
df.shape
# Out:
# (12660, 4)

# %%
df.drop(df.index[9693:], inplace = True)
df.drop(df.index[15:101],inplace=True)
df.shape
# Out:
# (9607, 4)

# %%
df.head(20)
# Out:
#      seq                 title          writer  \
# 0      1                붕어빵 ㅋㅋ            강신12
# 1      2              빼빼로 먹는날🤎        소라게 ENFJ
# 2      3  아침으로 먹을 맘모스빵을 사왔어요.😋        예사소년enfp
# 3      4           미라클 모닝 8일차.       RDFS INTJ
# 4      5   인팁이 분석능력 있어서 참 좋다.,     병맛intpA 5w6
# 5      6            마땅히 해야 할 일    넬리치 ENFJ 9w1
# 6      7               My type   멜랑꼴리ENTPj 1w8
# 7      8                진인사대천명         위대한 냥냥이
# 8      9       여자가 남자를 먼저 챙기다니    우지 핑크대지 ENTJ
# 9     10   넘 추워져서 샤워하기 힘들어요 엉엉              냥ㄴ
# 10    11    당연한 이야기를 일깨워드리겠읍니다   멜랑꼴리ENTPj 1w8
# 11    12                     .           XoxoX
# 12    13   님들은 어디서 동기부여를 얻으시나요   멜랑꼴리ENTPj 1w8
# 13    14              보람찬 하루..  필연적환상 Entj 3w4
# 14    15        요즘 무슨 재미로 사시나용              냥ㄴ
# 101  102    당연한 이야기를 일깨워드리겠읍니다   멜랑꼴리ENTPj 1w8
# 102  103                     .           XoxoX
# 103  104   님들은 어디서 동기부여를 얻으시나요   멜랑꼴리ENTPj 1w8
# 104  105              보람찬 하루..  필연적환상 Entj 3w4
# ...

# %%
df.tail()
# Out:
#        seq                        title           writer  \
# 9688  9691                         직장은따         오나비 isfj
# 9689  9692  전 프로필뮤직 제가 정말 꽂힌 노래로만 해놓는데요              뚱둘기
# 9690  9693            도로주행시험 떨어졌는디 ㅠㅠㅠㅠ  건국우유 ISTJ T 3w2
# 9691  9694       타고난 성격, 기질이라는 게 참 신기해요           뽀또뽀또뽀또
# 9692  9695              머리 이쁘다고 해주세용 :)          하날 ESFP
#
#                                                 content
# 9688  일땐 어떻게 해야할까요...?  저는 일단 신규 4개월 다되어가구요저희팀이 팀장님빼...
# 9689  정말 정말 꽂힌 노래 있잖아요몇년 질려도 안 질릴 것 같다 이거 진짜 너무 좋은 노...
# 9690  2번째엔 합격 할 수 있을까요? 1. 필기시험  78점 합격2. 장내기능  90점 ...
# 9691  저희 언니가 고등학생때 mbti를 처음으로 검사했었는데 그때는 intj가 나왔었지만...
# 9692        제가 엎드려 절받기도 정말 좋아하거든요.. 헤헤우리 엠헬 쓴생님들 사랑합니다

# %%
df.to_csv('./신변잡기_2.csv')
